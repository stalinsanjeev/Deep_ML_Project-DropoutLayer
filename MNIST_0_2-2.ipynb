# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images / 255.0
test_images = test_images / 255.0

model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])


model.compile(optimizer=Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_images, train_labels, epochs=5, validation_split=0.2)


test_loss, test_acc = model.evaluate(test_images, test_labels)


error_percentage = (1 - test_acc) * 100


print('Test accuracy:', test_acc)
print('Error percentage:', error_percentage)


import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 15s 9ms/step - loss: 0.3276 - accuracy: 0.8990 - val_loss: 0.1523 - val_accuracy: 0.9535
# Epoch 2/5
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1588 - accuracy: 0.9525 - val_loss: 0.1100 - val_accuracy: 0.9671
# Epoch 3/5
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1214 - accuracy: 0.9625 - val_loss: 0.0958 - val_accuracy: 0.9699
# Epoch 4/5
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1008 - accuracy: 0.9681 - val_loss: 0.0840 - val_accuracy: 0.9748
# Epoch 5/5
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0910 - accuracy: 0.9720 - val_loss: 0.0924 - val_accuracy: 0.9730
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0835 - accuracy: 0.9737
# Test accuracy: 0.9736999869346619
# Error percentage: 2.6300013065338135

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images / 255.0
test_images = test_images / 255.0


model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])


model.compile(optimizer=Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_images, train_labels, epochs=10, validation_split=0.2)


test_loss, test_acc = model.evaluate(test_images, test_labels)


error_percentage = (1 - test_acc) * 100


print('Test accuracy:', test_acc)
print('Error percentage:', error_percentage)


import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.3365 - accuracy: 0.8976 - val_loss: 0.1434 - val_accuracy: 0.9560
# Epoch 2/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1589 - accuracy: 0.9509 - val_loss: 0.1126 - val_accuracy: 0.9667
# Epoch 3/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1219 - accuracy: 0.9629 - val_loss: 0.0991 - val_accuracy: 0.9700
# Epoch 4/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1044 - accuracy: 0.9679 - val_loss: 0.0954 - val_accuracy: 0.9722
# Epoch 5/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0892 - accuracy: 0.9715 - val_loss: 0.0930 - val_accuracy: 0.9734
# Epoch 6/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0804 - accuracy: 0.9735 - val_loss: 0.0865 - val_accuracy: 0.9743
# Epoch 7/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0729 - accuracy: 0.9767 - val_loss: 0.0810 - val_accuracy: 0.9780
# Epoch 8/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0659 - accuracy: 0.9789 - val_loss: 0.0861 - val_accuracy: 0.9759
# Epoch 9/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0620 - accuracy: 0.9796 - val_loss: 0.0846 - val_accuracy: 0.9768
# Epoch 10/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0577 - accuracy: 0.9810 - val_loss: 0.0862 - val_accuracy: 0.9767
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0805 - accuracy: 0.9781
# Test accuracy: 0.9781000018119812
# Error percentage: 2.18999981880188

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images / 255.0
test_images = test_images / 255.0


model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])


model.compile(optimizer=Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_images, train_labels, epochs=20, validation_split=0.2)

test_loss, test_acc = model.evaluate(test_images, test_labels)


error_percentage = (1 - test_acc) * 100


print('Test accuracy:', test_acc)
print('Error percentage:', error_percentage)


import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.3362 - accuracy: 0.8986 - val_loss: 0.1388 - val_accuracy: 0.9583
# Epoch 2/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1596 - accuracy: 0.9518 - val_loss: 0.1133 - val_accuracy: 0.9645
# Epoch 3/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1207 - accuracy: 0.9632 - val_loss: 0.1069 - val_accuracy: 0.9678
# Epoch 4/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1028 - accuracy: 0.9681 - val_loss: 0.0941 - val_accuracy: 0.9712
# Epoch 5/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0910 - accuracy: 0.9714 - val_loss: 0.0895 - val_accuracy: 0.9737
# Epoch 6/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0800 - accuracy: 0.9740 - val_loss: 0.0910 - val_accuracy: 0.9722
# Epoch 7/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0717 - accuracy: 0.9768 - val_loss: 0.0894 - val_accuracy: 0.9762
# Epoch 8/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0681 - accuracy: 0.9782 - val_loss: 0.0784 - val_accuracy: 0.9773
# Epoch 9/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0618 - accuracy: 0.9801 - val_loss: 0.0908 - val_accuracy: 0.9753
# Epoch 10/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0571 - accuracy: 0.9810 - val_loss: 0.0864 - val_accuracy: 0.9762
# Epoch 11/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0533 - accuracy: 0.9827 - val_loss: 0.0852 - val_accuracy: 0.9772
# Epoch 12/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0530 - accuracy: 0.9824 - val_loss: 0.0925 - val_accuracy: 0.9776
# Epoch 13/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0506 - accuracy: 0.9840 - val_loss: 0.0863 - val_accuracy: 0.9778
# Epoch 14/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0491 - accuracy: 0.9837 - val_loss: 0.0902 - val_accuracy: 0.9770
# Epoch 15/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0435 - accuracy: 0.9858 - val_loss: 0.0909 - val_accuracy: 0.9769
# Epoch 16/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0449 - accuracy: 0.9859 - val_loss: 0.0864 - val_accuracy: 0.9787
# Epoch 17/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0418 - accuracy: 0.9861 - val_loss: 0.0899 - val_accuracy: 0.9780
# Epoch 18/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0404 - accuracy: 0.9872 - val_loss: 0.1030 - val_accuracy: 0.9759
# Epoch 19/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0382 - accuracy: 0.9878 - val_loss: 0.0911 - val_accuracy: 0.9797
# Epoch 20/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0378 - accuracy: 0.9871 - val_loss: 0.0845 - val_accuracy: 0.9807
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0793 - accuracy: 0.9817
# Test accuracy: 0.9817000031471252
# Error percentage: 1.8299996852874756

# %% [markdown]
# ## NO epoch = 50

# %% [markdown]
# 0.2 Epoch = 50

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images / 255.0
test_images = test_images / 255.0


model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])


model.compile(optimizer=Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_images, train_labels, epochs=50, validation_split=0.2)


test_loss, test_acc = model.evaluate(test_images, test_labels)


error_percentage = (1 - test_acc) * 100


print('Test accuracy:', test_acc)
print('Error percentage:', error_percentage)


import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.3296 - accuracy: 0.9001 - val_loss: 0.1388 - val_accuracy: 0.9573
# Epoch 2/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1566 - accuracy: 0.9525 - val_loss: 0.1105 - val_accuracy: 0.9671
# Epoch 3/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1201 - accuracy: 0.9632 - val_loss: 0.1127 - val_accuracy: 0.9643
# Epoch 4/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1039 - accuracy: 0.9675 - val_loss: 0.1010 - val_accuracy: 0.9702
# Epoch 5/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0883 - accuracy: 0.9714 - val_loss: 0.0960 - val_accuracy: 0.9719
# Epoch 6/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0797 - accuracy: 0.9751 - val_loss: 0.0878 - val_accuracy: 0.9744
# Epoch 7/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0716 - accuracy: 0.9769 - val_loss: 0.0927 - val_accuracy: 0.9734
# Epoch 8/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0679 - accuracy: 0.9785 - val_loss: 0.0888 - val_accuracy: 0.9758
# Epoch 9/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0619 - accuracy: 0.9797 - val_loss: 0.0835 - val_accuracy: 0.9764
# Epoch 10/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0593 - accuracy: 0.9809 - val_loss: 0.0899 - val_accuracy: 0.9770
# Epoch 11/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0552 - accuracy: 0.9820 - val_loss: 0.0933 - val_accuracy: 0.9747
# Epoch 12/50
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0534 - accuracy: 0.9824 - val_loss: 0.0863 - val_accuracy: 0.9791
# Epoch 13/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0487 - accuracy: 0.9841 - val_loss: 0.0825 - val_accuracy: 0.9787
# Epoch 14/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0481 - accuracy: 0.9842 - val_loss: 0.0860 - val_accuracy: 0.9780
# Epoch 15/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0449 - accuracy: 0.9852 - val_loss: 0.0875 - val_accuracy: 0.9793
# Epoch 16/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0423 - accuracy: 0.9861 - val_loss: 0.0863 - val_accuracy: 0.9772
# Epoch 17/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0424 - accuracy: 0.9859 - val_loss: 0.0911 - val_accuracy: 0.9775
# Epoch 18/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0391 - accuracy: 0.9872 - val_loss: 0.0922 - val_accuracy: 0.9790
# Epoch 19/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0412 - accuracy: 0.9865 - val_loss: 0.0907 - val_accuracy: 0.9789
# Epoch 20/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0385 - accuracy: 0.9876 - val_loss: 0.0974 - val_accuracy: 0.9783
# Epoch 21/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0360 - accuracy: 0.9878 - val_loss: 0.0967 - val_accuracy: 0.9787
# Epoch 22/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0371 - accuracy: 0.9879 - val_loss: 0.0934 - val_accuracy: 0.9802
# Epoch 23/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0358 - accuracy: 0.9886 - val_loss: 0.1022 - val_accuracy: 0.9787
# Epoch 24/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0392 - accuracy: 0.9871 - val_loss: 0.0945 - val_accuracy: 0.9790
# Epoch 25/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0342 - accuracy: 0.9886 - val_loss: 0.0953 - val_accuracy: 0.9807
# Epoch 26/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0326 - accuracy: 0.9886 - val_loss: 0.0971 - val_accuracy: 0.9799
# Epoch 27/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0341 - accuracy: 0.9891 - val_loss: 0.0939 - val_accuracy: 0.9810
# Epoch 28/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0303 - accuracy: 0.9898 - val_loss: 0.0984 - val_accuracy: 0.9803
# Epoch 29/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0312 - accuracy: 0.9896 - val_loss: 0.1022 - val_accuracy: 0.9791
# Epoch 30/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0324 - accuracy: 0.9898 - val_loss: 0.1011 - val_accuracy: 0.9812
# Epoch 31/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0300 - accuracy: 0.9900 - val_loss: 0.0960 - val_accuracy: 0.9797
# Epoch 32/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0311 - accuracy: 0.9905 - val_loss: 0.1070 - val_accuracy: 0.9803
# Epoch 33/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0290 - accuracy: 0.9906 - val_loss: 0.1005 - val_accuracy: 0.9817
# Epoch 34/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0300 - accuracy: 0.9909 - val_loss: 0.1059 - val_accuracy: 0.9791
# Epoch 35/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0280 - accuracy: 0.9910 - val_loss: 0.1010 - val_accuracy: 0.9797
# Epoch 36/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0280 - accuracy: 0.9910 - val_loss: 0.1021 - val_accuracy: 0.9809
# Epoch 37/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0257 - accuracy: 0.9920 - val_loss: 0.1082 - val_accuracy: 0.9787
# Epoch 38/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0295 - accuracy: 0.9906 - val_loss: 0.1077 - val_accuracy: 0.9811
# Epoch 39/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0300 - accuracy: 0.9907 - val_loss: 0.1034 - val_accuracy: 0.9809
# Epoch 40/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0295 - accuracy: 0.9909 - val_loss: 0.1059 - val_accuracy: 0.9810
# Epoch 41/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0276 - accuracy: 0.9914 - val_loss: 0.1089 - val_accuracy: 0.9809
# Epoch 42/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0255 - accuracy: 0.9920 - val_loss: 0.1053 - val_accuracy: 0.9789
# Epoch 43/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0260 - accuracy: 0.9914 - val_loss: 0.1090 - val_accuracy: 0.9802
# Epoch 44/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0259 - accuracy: 0.9920 - val_loss: 0.1046 - val_accuracy: 0.9806
# Epoch 45/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0273 - accuracy: 0.9916 - val_loss: 0.1128 - val_accuracy: 0.9790
# Epoch 46/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0259 - accuracy: 0.9923 - val_loss: 0.1126 - val_accuracy: 0.9804
# Epoch 47/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0264 - accuracy: 0.9920 - val_loss: 0.1186 - val_accuracy: 0.9783
# Epoch 48/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0283 - accuracy: 0.9917 - val_loss: 0.1119 - val_accuracy: 0.9789
# Epoch 49/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0239 - accuracy: 0.9928 - val_loss: 0.1151 - val_accuracy: 0.9787
# Epoch 50/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0247 - accuracy: 0.9921 - val_loss: 0.1191 - val_accuracy: 0.9803
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1181 - accuracy: 0.9792
# Test accuracy: 0.979200005531311
# Error percentage: 2.0799994468688965

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images / 255.0
test_images = test_images / 255.0


model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),

    Dense(128, activation='relu'),

    Dense(10, activation='softmax')
])


model.compile(optimizer=Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_images, train_labels, epochs=50, validation_split=0.2)


test_loss, test_acc = model.evaluate(test_images, test_labels)


error_percentage = (1 - test_acc) * 100


print('Test accuracy:', test_acc)
print('Error percentage:', error_percentage)


import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2531 - accuracy: 0.9256 - val_loss: 0.1236 - val_accuracy: 0.9637
# Epoch 2/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1055 - accuracy: 0.9678 - val_loss: 0.1111 - val_accuracy: 0.9658
# Epoch 3/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0715 - accuracy: 0.9777 - val_loss: 0.0963 - val_accuracy: 0.9727
# Epoch 4/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0557 - accuracy: 0.9821 - val_loss: 0.0966 - val_accuracy: 0.9720
# Epoch 5/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0426 - accuracy: 0.9859 - val_loss: 0.0886 - val_accuracy: 0.9745
# Epoch 6/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0359 - accuracy: 0.9878 - val_loss: 0.0939 - val_accuracy: 0.9742
# Epoch 7/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0273 - accuracy: 0.9911 - val_loss: 0.0964 - val_accuracy: 0.9748
# Epoch 8/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0253 - accuracy: 0.9919 - val_loss: 0.1055 - val_accuracy: 0.9741
# Epoch 9/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0219 - accuracy: 0.9926 - val_loss: 0.0924 - val_accuracy: 0.9773
# Epoch 10/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0177 - accuracy: 0.9945 - val_loss: 0.1062 - val_accuracy: 0.9762
# Epoch 11/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0182 - accuracy: 0.9942 - val_loss: 0.1453 - val_accuracy: 0.9700
# Epoch 12/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0142 - accuracy: 0.9949 - val_loss: 0.1149 - val_accuracy: 0.9750
# Epoch 13/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0147 - accuracy: 0.9947 - val_loss: 0.1095 - val_accuracy: 0.9773
# Epoch 14/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 0.1193 - val_accuracy: 0.9765
# Epoch 15/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0135 - accuracy: 0.9953 - val_loss: 0.1463 - val_accuracy: 0.9718
# Epoch 16/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.1397 - val_accuracy: 0.9726
# Epoch 17/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0090 - accuracy: 0.9966 - val_loss: 0.1392 - val_accuracy: 0.9723
# Epoch 18/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 0.1403 - val_accuracy: 0.9755
# Epoch 19/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.1469 - val_accuracy: 0.9759
# Epoch 20/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.1535 - val_accuracy: 0.9768
# Epoch 21/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.1699 - val_accuracy: 0.9724
# Epoch 22/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.1534 - val_accuracy: 0.9768
# Epoch 23/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.1632 - val_accuracy: 0.9774
# Epoch 24/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.1605 - val_accuracy: 0.9753
# Epoch 25/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.1574 - val_accuracy: 0.9761
# Epoch 26/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.1534 - val_accuracy: 0.9778
# Epoch 27/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.1629 - val_accuracy: 0.9775
# Epoch 28/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.1775 - val_accuracy: 0.9752
# Epoch 29/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.1839 - val_accuracy: 0.9768
# Epoch 30/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.1737 - val_accuracy: 0.9785
# Epoch 31/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.1899 - val_accuracy: 0.9760
# Epoch 32/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0098 - accuracy: 0.9972 - val_loss: 0.1733 - val_accuracy: 0.9783
# Epoch 33/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.1783 - val_accuracy: 0.9764
# Epoch 34/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0100 - accuracy: 0.9972 - val_loss: 0.1834 - val_accuracy: 0.9780
# Epoch 35/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.1803 - val_accuracy: 0.9782
# Epoch 36/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0093 - accuracy: 0.9975 - val_loss: 0.1897 - val_accuracy: 0.9766
# Epoch 37/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.1861 - val_accuracy: 0.9772
# Epoch 38/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.2028 - val_accuracy: 0.9758
# Epoch 39/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.2028 - val_accuracy: 0.9767
# Epoch 40/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.2370 - val_accuracy: 0.9728
# Epoch 41/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.2218 - val_accuracy: 0.9747
# Epoch 42/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.2095 - val_accuracy: 0.9766
# Epoch 43/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.2236 - val_accuracy: 0.9740
# Epoch 44/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.2438 - val_accuracy: 0.9743
# Epoch 45/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.1990 - val_accuracy: 0.9766
# Epoch 46/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.2099 - val_accuracy: 0.9767
# Epoch 47/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.2287 - val_accuracy: 0.9768
# Epoch 48/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.2363 - val_accuracy: 0.9767
# Epoch 49/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.2307 - val_accuracy: 0.9766
# Epoch 50/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.2399 - val_accuracy: 0.9772
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2132 - accuracy: 0.9763
# Test accuracy: 0.9763000011444092
# Error percentage: 2.369999885559082
